# %%
from agents.flight_agent import search_flights_openai
from agents.hotel_agent import search_hotels_openai
from agents.activity_agent import search_activities_openai
from agents.visa_agent import search_visa_openai
from agents.budget_agent import calculate_budget_plan
# Out:
# /home/tanisha.ramani@simform.dom/Desktop/github-posts/MULTIAGENTIC/0my_multiagent_travel_planner/agents/visa_agent.py:7: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   llm = ChatOpenAI(temperature=0, model="gpt-4", openai_api_key=openai_api_key)
# /home/tanisha.ramani@simform.dom/Desktop/github-posts/MULTIAGENTIC/0my_multiagent_travel_planner/agents/visa_agent.py:10: LangChainDeprecationWarning: The function `initialize_agent` was deprecated in LangChain 0.1.0 and will be removed in 1.0. Use Use new agent constructor methods like create_react_agent, create_json_agent, create_structured_chat_agent, etc. instead.
#   agent = initialize_agent(
# /home/tanisha.ramani@simform.dom/Desktop/github-posts/MULTIAGENTIC/0my_multiagent_travel_planner/agents/visa_agent.py:20: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   response = visa_agent_call.run("Visa requirements for Indian citizen traveling to USA")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_visa_openai` with `{'nationality': 'Indian', 'destination_country': 'USA'}`
# /home/tanisha.ramani@simform.dom/Desktop/github-posts/MULTIAGENTIC/0my_multiagent_travel_planner/tools/visa_tool.py:29: LangChainDeprecationWarning: The method `BaseChatModel.predict` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use invoke instead.
#   response = llm.predict(prompt)
# - Visa Requirement: Yes, a citizen of India is required to obtain a visa to travel to the USA.
# - Type of Visa: The type of visa required depends on the purpose of the visit. For tourism or business visits, a B1/B2 visa is typically required. For work, an H1B, L1, or other work visa may be needed. For studying, an F1 visa is required.
# - Duration of Stay: The duration of stay is determined by the type of visa. For a B1/B2 visa, the duration is typically up to 6 months. For work or student visas, the duration is usually for the period of employment or study.
# - Key Documents Required:
#   - A valid passport with at least six months validity beyond the planned date of departure from the USA.
#   - Completed visa application form (DS-160 for non-immigrant visas).
#   - Visa application fee payment receipt.
#   - Passport-sized photographs as per US visa specifications.
#   - Proof of financial means to cover the stay in the USA (like bank statements, salary slips, etc.).
#   - For work or student visas, additional documents like offer letters from the employer or admission letters from the educational institution may be required.
# - Disclaimer: This is a general guidance and the exact requirements may vary. Please consult the official website of the US Department of State or the US embassy or consulate in India for the most accurate and up-to-date information.As an Indian citizen, you are required to obtain a visa to travel to the USA. The type of visa you need depends on the purpose of your visit.
#
# - For tourism or business visits, a B1/B2 visa is typically required.
# - For work, an H1B, L1, or other work visa may be needed.
# - For studying, an F1 visa is required.
#
# The duration of stay is determined by the type of visa. For a B1/B2 visa, the duration is typically up to 6 months. For work or student visas, the duration is usually for the period of employment or study.
#
# Key documents required include:
#
# - A valid passport with at least six months validity beyond the planned date of departure from the USA.
# - Completed visa application form (DS-160 for non-immigrant visas).
# - Visa application fee payment receipt.
# - Passport-sized photographs as per US visa specifications.
# - Proof of financial means to cover the stay in the USA (like bank statements, salary slips, etc.).
# - For work or student visas, additional documents like offer letters from the employer or admission letters from the educational institution may be required.
#
# Please note that this is a general guidance and the exact requirements may vary. It's recommended to consult the official website of the US Department of State or the US embassy or consulate in India for the most accurate and up-to-date information.
#
# > Finished chain.
# As an Indian citizen, you are required to obtain a visa to travel to the USA. The type of visa you need depends on the purpose of your visit.
#
# - For tourism or business visits, a B1/B2 visa is typically required.
# - For work, an H1B, L1, or other work visa may be needed.
# - For studying, an F1 visa is required.
#
# The duration of stay is determined by the type of visa. For a B1/B2 visa, the duration is typically up to 6 months. For work or student visas, the duration is usually for the period of employment or study.
#
# Key documents required include:
#
# - A valid passport with at least six months validity beyond the planned date of departure from the USA.
# - Completed visa application form (DS-160 for non-immigrant visas).
# - Visa application fee payment receipt.
# - Passport-sized photographs as per US visa specifications.
# - Proof of financial means to cover the stay in the USA (like bank statements, salary slips, etc.).
# - For work or student visas, additional documents like offer letters from the employer or admission letters from the educational institution may be required.
#
# Please note that this is a general guidance and the exact requirements may vary. It's recommended to consult the official website of the US Department of State or the US embassy or consulate in India for the most accurate and up-to-date information.

# %% [markdown]
# ---

# %%
from agents.flight_agent import get_flight_agent
flight_agent = get_flight_agent()
response = flight_agent.run("flight options from Mumbai to Melbourne on May 24, 2025")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_flights_openai` with `{'origin': 'Mumbai', 'destination': 'Melbourne', 'date': '2025-05-24'}`
#
#
# Option 1:
# - Airline: Air India
# - Departure: 20:00, Arrival: 15:30 (+1 day)
# - Duration: 13h 30m
# - Estimated Price: INR 55,000
# - Booking: [www.airindia.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 2:
# - Airline: Qantas Airways
# - Departure: 22:30, Arrival: 18:00 (+1 day)
# - Duration: 14h 30m
# - Estimated Price: INR 60,000
# - Booking: [www.qantas.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 3:
# - Airline: Emirates
# - Departure: 04:30, Arrival: 20:00
# - Duration: 11h 30m (1 stop)
# - Estimated Price: INR 65,000
# - Booking: [www.emirates.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 4:
# - Airline: Singapore Airlines
# - Departure: 23:45, Arrival: 19:15 (+1 day)
# - Duration: 13h 30m
# - Estimated Price: INR 58,000
# - Booking: [www.singaporeair.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 5:
# - Airline: Cathay Pacific
# - Departure: 01:15, Arrival: 10:45
# - Duration: 13h 30m (1 stop)
# - Estimated Price: INR 62,000
# - Booking: [www.cathaypacific.com/booking/MUM-MEL/2025-05-24](#)Here are some flight options from Mumbai to Melbourne on May 24, 2025:
#
# 1. [Air India](#): Departure at 20:00, Arrival at 15:30 (+1 day). The duration of the flight is 13h 30m. The estimated price is INR 55,000.
#
# 2. [Qantas Airways](#): Departure at 22:30, Arrival at 18:00 (+1 day). The duration of the flight is 14h 30m. The estimated price is INR 60,000.
#
# 3. [Emirates](#): Departure at 04:30, Arrival at 20:00. The duration of the flight is 11h 30m with 1 stop. The estimated price is INR 65,000.
#
# 4. [Singapore Airlines](#): Departure at 23:45, Arrival at 19:15 (+1 day). The duration of the flight is 13h 30m. The estimated price is INR 58,000.
#
# 5. [Cathay Pacific](#): Departure at 01:15, Arrival at 10:45. The duration of the flight is 13h 30m with 1 stop. The estimated price is INR 62,000.
#
# Please note that these are estimated prices and the actual prices may vary. You can click on the airline name to go to the booking page.
#
# > Finished chain.

# %%
print(response)
# Out:
# Here are some flight options from Mumbai to Melbourne on May 24, 2025:
#
# 1. [Air India](#): Departure at 20:00, Arrival at 15:30 (+1 day). The duration of the flight is 13h 30m. The estimated price is INR 55,000.
#
# 2. [Qantas Airways](#): Departure at 22:30, Arrival at 18:00 (+1 day). The duration of the flight is 14h 30m. The estimated price is INR 60,000.
#
# 3. [Emirates](#): Departure at 04:30, Arrival at 20:00. The duration of the flight is 11h 30m with 1 stop. The estimated price is INR 65,000.
#
# 4. [Singapore Airlines](#): Departure at 23:45, Arrival at 19:15 (+1 day). The duration of the flight is 13h 30m. The estimated price is INR 58,000.
#
# 5. [Cathay Pacific](#): Departure at 01:15, Arrival at 10:45. The duration of the flight is 13h 30m with 1 stop. The estimated price is INR 62,000.
#
# Please note that these are estimated prices and the actual prices may vary. You can click on the airline name to go to the booking page.

# %%
from agents.hotel_agent import get_hotel_agent

hotel_agent = get_hotel_agent()
response = hotel_agent.run("hotel options in Melbourne from May 24 to May 30, 2025 under $200")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_hotels_openai` with `{'to_city': 'Melbourne', 'check_in': '2025-05-24', 'check_out': '2025-05-30', 'hotel_budget': 200}`
#
#
# I'm sorry, but it's highly unlikely to find hotels in Melbourne that would fit within a total budget of $200 for a 6-night stay. The average price per night for a hotel in Melbourne is typically over $100. However, I can suggest some budget-friendly options that might stretch your budget a little further:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget-friendly hotel offers basic amenities and is close to public transportation, making it easy to explore the city. It's a good fit for budget travelers.
#    - Estimated price/night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This budget hotel located in Melbourne CBD offers dormitory-style rooms and private rooms. It's a great option for backpackers or solo travelers.
#    - Estimated price/night: $60
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located close to Queen Victoria Market. It offers both private rooms and dormitory-style rooms. It's suitable for backpackers and solo travelers.
#    - Estimated price/night: $50
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices are subject to change and may vary depending on the booking date and availability.Here are some budget-friendly hotel options in Melbourne for your stay from May 24 to May 30, 2025:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget-friendly hotel offers basic amenities and is close to public transportation, making it easy to explore the city. It's a good fit for budget travelers.
#    - Estimated price per night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This budget hotel located in Melbourne CBD offers dormitory-style rooms and private rooms. It's a great option for backpackers or solo travelers.
#    - Estimated price per night: $60
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located close to Queen Victoria Market. It offers both private rooms and dormitory-style rooms. It's suitable for backpackers and solo travelers.
#    - Estimated price per night: $50
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices are subject to change and may vary depending on the booking date and availability.
#
# > Finished chain.

# %%
print(response)
# Out:
# Here are some budget-friendly hotel options in Melbourne for your stay from May 24 to May 30, 2025:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget-friendly hotel offers basic amenities and is close to public transportation, making it easy to explore the city. It's a good fit for budget travelers.
#    - Estimated price per night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This budget hotel located in Melbourne CBD offers dormitory-style rooms and private rooms. It's a great option for backpackers or solo travelers.
#    - Estimated price per night: $60
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located close to Queen Victoria Market. It offers both private rooms and dormitory-style rooms. It's suitable for backpackers and solo travelers.
#    - Estimated price per night: $50
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices are subject to change and may vary depending on the booking date and availability.

# %%
from agents.activity_agent import get_activity_agent
activity_agent = get_activity_agent()
response = activity_agent.run("activities in Melbourne from May 24 to May 30, 2025 under $100")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_activities_openai` with `{'to_city': 'Melbourne', 'travel_days': 7, 'interests': ['budget-friendly']}`
#
#
# Day 1:
# - Activity: Melbourne Free Walking Tour
#   Description: Discover Melbourne's rich history and culture on this 3-hour walking tour.
#   Type: Cultural
#   Booking: www.melbournefreewalkingtours.com
#
# - Activity: Visit Queen Victoria Market
#   Description: Explore the largest open-air market in the Southern Hemisphere, offering a variety of fresh produce, food, and unique souvenirs.
#   Type: Food/Cultural
#   Reference: www.qvm.com.au
#
# Day 2:
# - Activity: Visit the State Library of Victoria
#   Description: Explore Australia's oldest public library, home to over 2 million books and 16,000 serials.
#   Type: Cultural
#   Reference: www.slv.vic.gov.au
#
# Day 3:
# - Activity: Explore the Royal Botanic Gardens
#   Description: Enjoy a peaceful stroll through this 38-hectare garden, home to over 10,000 individual species.
#   Type: Adventure
#   Reference: www.rbg.vic.gov.au
#
# Day 4:
# - Activity: Visit the National Gallery of Victoria
#   Description: Explore Australia's oldest and most visited art museum, featuring over 70,000 works of art.
#   Type: Cultural
#   Reference: www.ngv.vic.gov.au
#
# Day 5:
# - Activity: Explore St Kilda Beach
#   Description: Enjoy a day at this popular beach, known for its stunning views, vibrant atmosphere, and iconic pier.
#   Type: Adventure
#   Reference: www.visitstkilda.com.au
#
# Day 6:
# - Activity: Visit the Melbourne Museum
#   Description: Explore this award-winning museum, featuring exhibits on history, culture, science, and nature.
#   Type: Cultural
#   Reference: www.museumsvictoria.com.au/melbournemuseum
#
# Day 7:
# - Activity: Explore the Dandenong Ranges
#   Description: Enjoy a day of hiking and picnicking in this beautiful mountain range, located just outside of Melbourne.
#   Type: Adventure
#   Reference: www.visitdandenongranges.com.au
# Here are some budget-friendly activities you can do in Melbourne from May 24 to May 30, 2025:
#
# **Day 1:**
# - Melbourne Free Walking Tour: Discover Melbourne's rich history and culture on this 3-hour walking tour. [More info](www.melbournefreewalkingtours.com)
# - Visit Queen Victoria Market: Explore the largest open-air market in the Southern Hemisphere, offering a variety of fresh produce, food, and unique souvenirs. [More info](www.qvm.com.au)
#
# **Day 2:**
# - Visit the State Library of Victoria: Explore Australia's oldest public library, home to over 2 million books and 16,000 serials. [More info](www.slv.vic.gov.au)
#
# **Day 3:**
# - Explore the Royal Botanic Gardens: Enjoy a peaceful stroll through this 38-hectare garden, home to over 10,000 individual species. [More info](www.rbg.vic.gov.au)
#
# **Day 4:**
# - Visit the National Gallery of Victoria: Explore Australia's oldest and most visited art museum, featuring over 70,000 works of art. [More info](www.ngv.vic.gov.au)
#
# **Day 5:**
# - Explore St Kilda Beach: Enjoy a day at this popular beach, known for its stunning views, vibrant atmosphere, and iconic pier. [More info](www.visitstkilda.com.au)
#
# **Day 6:**
# - Visit the Melbourne Museum: Explore this award-winning museum, featuring exhibits on history, culture, science, and nature. [More info](www.museumsvictoria.com.au/melbournemuseum)
#
# **Day 7:**
# - Explore the Dandenong Ranges: Enjoy a day of hiking and picnicking in this beautiful mountain range, located just outside of Melbourne. [More info](www.visitdandenongranges.com.au)
#
# Please note that while these activities are generally free or low-cost, prices can change and it's always a good idea to check the official websites for the most up-to-date information. Enjoy your trip!
#
# > Finished chain.

# %%
print(response)
# Out:
# Here are some budget-friendly activities you can do in Melbourne from May 24 to May 30, 2025:
#
# **Day 1:**
# - Melbourne Free Walking Tour: Discover Melbourne's rich history and culture on this 3-hour walking tour. [More info](www.melbournefreewalkingtours.com)
# - Visit Queen Victoria Market: Explore the largest open-air market in the Southern Hemisphere, offering a variety of fresh produce, food, and unique souvenirs. [More info](www.qvm.com.au)
#
# **Day 2:**
# - Visit the State Library of Victoria: Explore Australia's oldest public library, home to over 2 million books and 16,000 serials. [More info](www.slv.vic.gov.au)
#
# **Day 3:**
# - Explore the Royal Botanic Gardens: Enjoy a peaceful stroll through this 38-hectare garden, home to over 10,000 individual species. [More info](www.rbg.vic.gov.au)
#
# **Day 4:**
# - Visit the National Gallery of Victoria: Explore Australia's oldest and most visited art museum, featuring over 70,000 works of art. [More info](www.ngv.vic.gov.au)
#
# **Day 5:**
# - Explore St Kilda Beach: Enjoy a day at this popular beach, known for its stunning views, vibrant atmosphere, and iconic pier. [More info](www.visitstkilda.com.au)
#
# **Day 6:**
# - Visit the Melbourne Museum: Explore this award-winning museum, featuring exhibits on history, culture, science, and nature. [More info](www.museumsvictoria.com.au/melbournemuseum)
#
# **Day 7:**
# - Explore the Dandenong Ranges: Enjoy a day of hiking and picnicking in this beautiful mountain range, located just outside of Melbourne. [More info](www.visitdandenongranges.com.au)
#
# Please note that while these activities are generally free or low-cost, prices can change and it's always a good idea to check the official websites for the most up-to-date information. Enjoy your trip!

# %%
from agents.visa_agent import get_visa_agent
visa_agent = get_visa_agent()
response = visa_agent.run("visa requirements for Indian citizens traveling to Australia")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_visa_openai` with `{'nationality': 'Indian', 'destination_country': 'Australia'}`
#
#
# - Visa Requirement: Yes, Indian citizens require a visa to travel to Australia.
# - Type of Visa: The type of visa required depends on the purpose of the visit. For tourism, a Visitor visa (subclass 600) is typically needed. For work, a Work visa (subclass 457) may be required. For studying, a Student visa (subclass 500) is usually necessary.
# - Duration of Stay: The duration of stay allowed varies depending on the visa type. For a Visitor visa, the stay can be up to 3, 6 or 12 months. For a Work visa, the stay can be up to 4 years. For a Student visa, the stay duration corresponds to the duration of the course.
# - Key Documents Typically Required: Passport, completed visa application form, visa application fee, proof of sufficient funds, proof of health insurance, police clearance certificate, and depending on the visa type, additional documents such as an invitation letter, employment contract, or proof of enrollment in a course may be required.
# - Disclaimer: This is a general guidance and the requirements may vary. Please consult the official website of the Australian Department of Home Affairs or contact the Australian embassy or consulate in India for the most accurate and up-to-date information.Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 457) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed varies depending on the visa type. For a Visitor visa, the stay can be up to 3, 6 or 12 months. For a Work visa, the stay can be up to 4 years. For a Student visa, the stay duration corresponds to the duration of the course.
#
# Key documents typically required include your passport, a completed visa application form, visa application fee, proof of sufficient funds, proof of health insurance, and a police clearance certificate. Depending on the visa type, additional documents such as an invitation letter, employment contract, or proof of enrollment in a course may be required.
#
# Please note that this is a general guidance and the requirements may vary. I recommend consulting the official website of the Australian Department of Home Affairs or contacting the Australian embassy or consulate in India for the most accurate and up-to-date information.
#
# > Finished chain.

# %%
print(response)
# Out:
# Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 457) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed varies depending on the visa type. For a Visitor visa, the stay can be up to 3, 6 or 12 months. For a Work visa, the stay can be up to 4 years. For a Student visa, the stay duration corresponds to the duration of the course.
#
# Key documents typically required include your passport, a completed visa application form, visa application fee, proof of sufficient funds, proof of health insurance, and a police clearance certificate. Depending on the visa type, additional documents such as an invitation letter, employment contract, or proof of enrollment in a course may be required.
#
# Please note that this is a general guidance and the requirements may vary. I recommend consulting the official website of the Australian Department of Home Affairs or contacting the Australian embassy or consulate in India for the most accurate and up-to-date information.

# %%
from agents.budget_agent import get_budget_agent
budget_agent = get_budget_agent()
response = budget_agent.run("budget plan for a trip to Melbourne from May 24 to May 30, 2025 with a budget of $2000")
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `calculate_budget_plan` with `{'budget': 2000, 'currency': 'USD'}`
#
#
# Trip Budget Planner:
# -----------------------
# Flights     : 800.0 USD
# Hotels      : 600.0 USD
# Activities  : 400.0 USD
# Other Costs : 200.0 USD
# -----------------------
# Total Budget: 2000.0 USDHere is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# The total budget for your trip is $2000.00.
#
# > Finished chain.

# %%
print(response)
# Out:
# Here is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# The total budget for your trip is $2000.00.

# %%
from agents.visa_agent import get_visa_agent
from agents.budget_agent import get_budget_agent
from agents.flight_agent import get_flight_agent
from agents.hotel_agent import get_hotel_agent
from agents.activity_agent import get_activity_agent

visa_agent = get_visa_agent()
budget_agent = get_budget_agent()
flight_agent = get_flight_agent()
hotel_agent = get_hotel_agent()
activity_agent = get_activity_agent()

visa_response = visa_agent.run("visa requirements for Indian citizens traveling to Australia")
budget_response = budget_agent.run("budget plan for a trip to Melbourne from May 24 to May 30, 2025 with a budget of $2000")
flight_response = flight_agent.run("flight options from Mumbai to Melbourne on May 24, 2025")
hotel_response = hotel_agent.run("hotel options in Melbourne from May 24 to May 30, 2025 under $200")
activity_response = activity_agent.run("activities in Melbourne from May 24 to May 30, 2025 under $100")

print("Visa Response:", visa_response)
print("Budget Response:", budget_response)
print("Flight Response:", flight_response)
print("Hotel Response:", hotel_response)
print("Activity Response:", activity_response)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_visa_openai` with `{'nationality': 'Indian', 'destination_country': 'Australia'}`
#
#
# - Visa Requirement: Yes, Indian citizens require a visa to travel to Australia.
# - Type of Visa: The type of visa required depends on the purpose of the visit. For tourism, a Visitor visa (subclass 600) is typically needed. For work, a Work visa (subclass 457) may be required. For studying, a Student visa (subclass 500) is usually necessary.
# - Duration of Stay: The duration of stay allowed varies depending on the visa type. For a Visitor visa, the stay can be up to 3, 6 or 12 months. For a Work visa, the stay can be up to 4 years. For a Student visa, the stay duration corresponds to the duration of the course.
# - Key Documents Typically Required:
#   - A valid Indian passport
#   - Completed Australian visa application form
#   - Passport-sized photographs
#   - Proof of sufficient funds to cover your stay
#   - For a Visitor visa, a detailed itinerary of your stay may be required
#   - For a Work visa, a nomination by an approved Australian employer is needed
#   - For a Student visa, a Confirmation of Enrolment (CoE) from an Australian educational institution is required
# - Disclaimer: This is a general guidance and the requirements may vary. Always consult official sources or the Australian embassy/consulate in India for the most accurate and up-to-date information.
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 457) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed varies depending on the visa type. For a Visitor visa, the stay can be up to 3, 6 or 12 months. For a Work visa, the stay can be up to 4 years. For a Student visa, the stay duration corresponds to the duration of the course.
#
# Key documents typically required include:
#
# - A valid Indian passport
# - Completed Australian visa application form
# - Passport-sized photographs
# - Proof of sufficient funds to cover your stay
# - For a Visitor visa, a detailed itinerary of your stay may be required
# - For a Work visa, a nomination by an approved Australian employer is needed
# - For a Student visa, a Confirmation of Enrolment (CoE) from an Australian educational institution is required
#
# Please note that this is a general guidance and the requirements may vary. Always consult official sources or the Australian embassy/consulate in India for the most accurate and up-to-date information.
#
# > Finished chain.
# Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 457) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed varies depending on the visa type. For a Visitor visa, the stay can be up to 3, 6 or 12 months. For a Work visa, the stay can be up to 4 years. For a Student visa, the stay duration corresponds to the duration of the course.
#
# Key documents typically required include:
#
# - A valid Indian passport
# - Completed Australian visa application form
# - Passport-sized photographs
# - Proof of sufficient funds to cover your stay
# - For a Visitor visa, a detailed itinerary of your stay may be required
# - For a Work visa, a nomination by an approved Australian employer is needed
# - For a Student visa, a Confirmation of Enrolment (CoE) from an Australian educational institution is required
#
# Please note that this is a general guidance and the requirements may vary. Always consult official sources or the Australian embassy/consulate in India for the most accurate and up-to-date information.
#
# --------------------------------------------------------------------------------
#
#
# Invoking: `calculate_budget_plan` with `{'budget': 2000, 'currency': 'USD'}`
#
#
# Trip Budget Planner:
# -----------------------
# Flights     : 800.0 USD
# Hotels      : 600.0 USD
# Activities  : 400.0 USD
# Other Costs : 200.0 USD
# -----------------------
# Total Budget: 2000.0 USD
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# The total budget for your trip is $2000.00.
#
# > Finished chain.
# Here is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# The total budget for your trip is $2000.00.
#
# --------------------------------------------------------------------------------
#
#
# Invoking: `search_flights_openai` with `{'origin': 'Mumbai', 'destination': 'Melbourne', 'date': '2025-05-24'}`
#
#
# 1. **Airline:** Air India
#    - **Departure:** 00:30
#    - **Arrival:** 15:30
#    - **Duration:** 15 hours
#    - **Price:** INR 45,000
#    - **Booking Link:** [www.airindia.com/booking/MUM-MEL/2025-05-24](#)
#
# 2. **Airline:** Qantas Airways
#    - **Departure:** 02:45
#    - **Arrival:** 18:00
#    - **Duration:** 15 hours 15 minutes
#    - **Price:** INR 55,000
#    - **Booking Link:** [www.qantas.com/booking/MUM-MEL/2025-05-24](#)
#
# 3. **Airline:** Emirates
#    - **Departure:** 04:15
#    - **Arrival:** 20:30
#    - **Duration:** 16 hours 15 minutes
#    - **Price:** INR 60,000
#    - **Booking Link:** [www.emirates.com/booking/MUM-MEL/2025-05-24](#)
#
# 4. **Airline:** Singapore Airlines
#    - **Departure:** 23:45
#    - **Arrival:** 14:30 (Next Day)
#    - **Duration:** 14 hours 45 minutes
#    - **Price:** INR 50,000
#    - **Booking Link:** [www.singaporeair.com/booking/MUM-MEL/2025-05-24](#)
#
# 5. **Airline:** Etihad Airways
#    - **Departure:** 21:30
#    - **Arrival:** 12:00 (Next Day)
#    - **Duration:** 14 hours 30 minutes
#    - **Price:** INR 52,000
#    - **Booking Link:** [www.etihad.com/booking/MUM-MEL/2025-05-24](#)
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here are some flight options for your travel from Mumbai to Melbourne on May 24, 2025:
#
# 1. [Air India](www.airindia.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 00:30
#    - Arrival: 15:30
#    - Duration: 15 hours
#    - Price: INR 45,000
#
# 2. [Qantas Airways](www.qantas.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 02:45
#    - Arrival: 18:00
#    - Duration: 15 hours 15 minutes
#    - Price: INR 55,000
#
# 3. [Emirates](www.emirates.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 04:15
#    - Arrival: 20:30
#    - Duration: 16 hours 15 minutes
#    - Price: INR 60,000
#
# 4. [Singapore Airlines](www.singaporeair.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 23:45
#    - Arrival: 14:30 (Next Day)
#    - Duration: 14 hours 45 minutes
#    - Price: INR 50,000
#
# 5. [Etihad Airways](www.etihad.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 21:30
#    - Arrival: 12:00 (Next Day)
#    - Duration: 14 hours 30 minutes
#    - Price: INR 52,000
#
# Please note that prices and availability are subject to change. It's always a good idea to book in advance to secure the best rates.
#
# > Finished chain.
# Here are some flight options for your travel from Mumbai to Melbourne on May 24, 2025:
#
# 1. [Air India](www.airindia.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 00:30
#    - Arrival: 15:30
#    - Duration: 15 hours
#    - Price: INR 45,000
#
# 2. [Qantas Airways](www.qantas.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 02:45
#    - Arrival: 18:00
#    - Duration: 15 hours 15 minutes
#    - Price: INR 55,000
#
# 3. [Emirates](www.emirates.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 04:15
#    - Arrival: 20:30
#    - Duration: 16 hours 15 minutes
#    - Price: INR 60,000
#
# 4. [Singapore Airlines](www.singaporeair.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 23:45
#    - Arrival: 14:30 (Next Day)
#    - Duration: 14 hours 45 minutes
#    - Price: INR 50,000
#
# 5. [Etihad Airways](www.etihad.com/booking/MUM-MEL/2025-05-24)
#    - Departure: 21:30
#    - Arrival: 12:00 (Next Day)
#    - Duration: 14 hours 30 minutes
#    - Price: INR 52,000
#
# Please note that prices and availability are subject to change. It's always a good idea to book in advance to secure the best rates.
#
# --------------------------------------------------------------------------------
#
#
# Invoking: `search_hotels_openai` with `{'to_city': 'Melbourne', 'check_in': '2025-05-24', 'check_out': '2025-05-30', 'hotel_budget': 600}`
#
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget-friendly hotel offers clean and comfortable rooms. It's perfect for travelers who want to explore the city without breaking the bank.
#    - Estimated price/night: $80
#    - [Book here](www.ibisbudgetmelbourne.com/booking?date=2025-05-24&nights=6)
#
# 2. **Space Hotel**
#    - This modern budget hotel is located in Melbourne's city center. It offers a range of rooms from shared dormitories to private rooms, making it suitable for all types of travelers.
#    - Estimated price/night: $90
#    - [Book here](www.spacehotel.com.au/booking?date=2025-05-24&nights=6)
#
# 3. **City Centre Budget Hotel**
#    - A charming budget hotel located in Melbourne's city center. It offers a comfortable stay with basic amenities, perfect for budget-conscious travelers.
#    - Estimated price/night: $85
#    - [Book here](www.citycentrebudgethotel.com/booking?date=2025-05-24&nights=6)
#
# 4. **The Victoria Hotel**
#    - An historic, budget-friendly hotel located in the heart of Melbourne. It offers comfortable rooms and is within walking distance to many of the city's attractions.
#    - Estimated price/night: $95
#    - [Book here](www.victoriahotel.com.au/booking?date=2025-05-24&nights=6)
#
# 5. **Melbourne Metro YHA**
#    - A budget-friendly hostel located in North Melbourne. It offers both private rooms and dormitories, making it suitable for solo travelers, couples, and groups.
#    - Estimated price/night: $70
#    - [Book here](www.melbournemetroyha.com.au/booking?date=2025-05-24&nights=6)
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here are some hotel options in Melbourne from May 24 to May 30, 2025, under $600:
#
# 1. [**Ibis Budget Melbourne CBD**](www.ibisbudgetmelbourne.com/booking?date=2025-05-24&nights=6)
#    - Located in the heart of Melbourne, this budget-friendly hotel offers clean and comfortable rooms. It's perfect for travelers who want to explore the city without breaking the bank.
#    - Estimated price/night: $80
#
# 2. [**Space Hotel**](www.spacehotel.com.au/booking?date=2025-05-24&nights=6)
#    - This modern budget hotel is located in Melbourne's city center. It offers a range of rooms from shared dormitories to private rooms, making it suitable for all types of travelers.
#    - Estimated price/night: $90
#
# 3. [**City Centre Budget Hotel**](www.citycentrebudgethotel.com/booking?date=2025-05-24&nights=6)
#    - A charming budget hotel located in Melbourne's city center. It offers a comfortable stay with basic amenities, perfect for budget-conscious travelers.
#    - Estimated price/night: $85
#
# 4. [**The Victoria Hotel**](www.victoriahotel.com.au/booking?date=2025-05-24&nights=6)
#    - An historic, budget-friendly hotel located in the heart of Melbourne. It offers comfortable rooms and is within walking distance to many of the city's attractions.
#    - Estimated price/night: $95
#
# 5. [**Melbourne Metro YHA**](www.melbournemetroyha.com.au/booking?date=2025-05-24&nights=6)
#    - A budget-friendly hostel located in North Melbourne. It offers both private rooms and dormitories, making it suitable for solo travelers, couples, and groups.
#    - Estimated price/night: $70
#
# Please note that prices are estimated and may vary. Be sure to check the booking links for the most accurate and up-to-date information.
#
# > Finished chain.
# Here are some hotel options in Melbourne from May 24 to May 30, 2025, under $600:
#
# 1. [**Ibis Budget Melbourne CBD**](www.ibisbudgetmelbourne.com/booking?date=2025-05-24&nights=6)
#    - Located in the heart of Melbourne, this budget-friendly hotel offers clean and comfortable rooms. It's perfect for travelers who want to explore the city without breaking the bank.
#    - Estimated price/night: $80
#
# 2. [**Space Hotel**](www.spacehotel.com.au/booking?date=2025-05-24&nights=6)
#    - This modern budget hotel is located in Melbourne's city center. It offers a range of rooms from shared dormitories to private rooms, making it suitable for all types of travelers.
#    - Estimated price/night: $90
#
# 3. [**City Centre Budget Hotel**](www.citycentrebudgethotel.com/booking?date=2025-05-24&nights=6)
#    - A charming budget hotel located in Melbourne's city center. It offers a comfortable stay with basic amenities, perfect for budget-conscious travelers.
#    - Estimated price/night: $85
#
# 4. [**The Victoria Hotel**](www.victoriahotel.com.au/booking?date=2025-05-24&nights=6)
#    - An historic, budget-friendly hotel located in the heart of Melbourne. It offers comfortable rooms and is within walking distance to many of the city's attractions.
#    - Estimated price/night: $95
#
# 5. [**Melbourne Metro YHA**](www.melbournemetroyha.com.au/booking?date=2025-05-24&nights=6)
#    - A budget-friendly hostel located in North Melbourne. It offers both private rooms and dormitories, making it suitable for solo travelers, couples, and groups.
#    - Estimated price/night: $70
#
# Please note that prices are estimated and may vary. Be sure to check the booking links for the most accurate and up-to-date information.
#
# --------------------------------------------------------------------------------
#
#
# Invoking: `search_activities_openai` with `{'to_city': 'Melbourne', 'travel_days': 7, 'interests': ['budget', 'under $400']}`
#
#
# Day 1:
# - Activity: Melbourne City Tour
#   Description: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a guided city tour.
#   Type: Cultural
#   Booking: www.melbournecitytours.com/booknow
#
# Day 2:
# - Activity: Queen Victoria Market
#   Description: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs.
#   Type: Food & Shopping
#   Reference: www.queenvictoriamarket.com.au/visit
#
# Day 3:
# - Activity: Melbourne Zoo
#   Description: Discover over 320 species from around the world in a beautifully landscaped setting.
#   Type: Adventure
#   Booking: www.melbournezoo.com.au/tickets
#
# Day 4:
# - Activity: Melbourne Museum
#   Description: Explore Australia's cultural history with exhibits on Aboriginal culture, the country's flora and fauna, and more.
#   Type: Cultural
#   Booking: www.melbournemuseum.com.au/visit
#
# Day 5:
# - Activity: Royal Botanic Gardens
#   Description: Enjoy a peaceful walk through lush gardens featuring over 8,500 plant species.
#   Type: Nature
#   Reference: www.rbg.vic.gov.au/visit-melbourne
#
# Day 6:
# - Activity: St Kilda Beach
#   Description: Relax on the sandy beach, enjoy water sports, or visit the nearby Luna Park amusement park.
#   Type: Adventure
#   Reference: www.visitstkilda.com.au
#
# Day 7:
# - Activity: Yarra Valley Wine Tour
#   Description: Enjoy a day trip to Yarra Valley, sampling wines at various vineyards and enjoying the beautiful scenery.
#   Type: Food & Adventure
#   Booking: www.yarravalleywinetours.com/booknow
#
# Please note that prices may vary and it's always good to check the websites for the most up-to-date information. Enjoy your trip!Here are some activities you can do in Melbourne from May 24 to May 30, 2025 under $400:
#
# Day 1:
# - **Melbourne City Tour**: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a guided city tour. [Book here](www.melbournecitytours.com/booknow)
#
# Day 2:
# - **Queen Victoria Market**: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs. [More info](www.queenvictoriamarket.com.au/visit)
#
# Day 3:
# - **Melbourne Zoo**: Discover over 320 species from around the world in a beautifully landscaped setting. [Book here](www.melbournezoo.com.au/tickets)
#
# Day 4:
# - **Melbourne Museum**: Explore Australia's cultural history with exhibits on Aboriginal culture, the country's flora and fauna, and more. [Book here](www.melbournemuseum.com.au/visit)
#
# Day 5:
# - **Royal Botanic Gardens**: Enjoy a peaceful walk through lush gardens featuring over 8,500 plant species. [More info](www.rbg.vic.gov.au/visit-melbourne)
#
# Day 6:
# - **St Kilda Beach**: Relax on the sandy beach, enjoy water sports, or visit the nearby Luna Park amusement park. [More info](www.visitstkilda.com.au)
#
# Day 7:
# - **Yarra Valley Wine Tour**: Enjoy a day trip to Yarra Valley, sampling wines at various vineyards and enjoying the beautiful scenery. [Book here](www.yarravalleywinetours.com/booknow)
#
# Please note that prices may vary and it's always good to check the websites for the most up-to-date information. Enjoy your trip!
#
# > Finished chain.
# Here are some activities you can do in Melbourne from May 24 to May 30, 2025 under $400:
#
# Day 1:
# - **Melbourne City Tour**: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a guided city tour. [Book here](www.melbournecitytours.com/booknow)
#
# Day 2:
# - **Queen Victoria Market**: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs. [More info](www.queenvictoriamarket.com.au/visit)
#
# Day 3:
# - **Melbourne Zoo**: Discover over 320 species from around the world in a beautifully landscaped setting. [Book here](www.melbournezoo.com.au/tickets)
#
# Day 4:
# - **Melbourne Museum**: Explore Australia's cultural history with exhibits on Aboriginal culture, the country's flora and fauna, and more. [Book here](www.melbournemuseum.com.au/visit)
#
# Day 5:
# - **Royal Botanic Gardens**: Enjoy a peaceful walk through lush gardens featuring over 8,500 plant species. [More info](www.rbg.vic.gov.au/visit-melbourne)
#
# Day 6:
# - **St Kilda Beach**: Relax on the sandy beach, enjoy water sports, or visit the nearby Luna Park amusement park. [More info](www.visitstkilda.com.au)
#
# Day 7:
# - **Yarra Valley Wine Tour**: Enjoy a day trip to Yarra Valley, sampling wines at various vineyards and enjoying the beautiful scenery. [Book here](www.yarravalleywinetours.com/booknow)
#
# Please note that prices may vary and it's always good to check the websites for the most up-to-date information. Enjoy your trip!
#
# --------------------------------------------------------------------------------

# %%
from agents.visa_agent import get_visa_agent
from agents.budget_agent import get_budget_agent
from agents.flight_agent import get_flight_agent
from agents.hotel_agent import get_hotel_agent
from agents.activity_agent import get_activity_agent

visa_agent = get_visa_agent()
budget_agent = get_budget_agent()
flight_agent = get_flight_agent()
hotel_agent = get_hotel_agent()
activity_agent = get_activity_agent()

visa_response = visa_agent.run("visa requirements for Indian citizens traveling to Australia")
budget_response = budget_agent.run("budget plan for a trip to Melbourne from May 24 to May 30, 2025 with a budget of $2000")
flight_response = flight_agent.run("flight options from Mumbai to Melbourne on May 24, 2025")
hotel_response = hotel_agent.run("hotel options in Melbourne from May 24 to May 30, 2025 under $200")
activity_response = activity_agent.run("activities in Melbourne from May 24 to May 30, 2025 under $100")

print("Visa Response:", visa_response)
print("Budget Response:", budget_response)
print("Flight Response:", flight_response)
print("Hotel Response:", hotel_response)
print("Activity Response:", activity_response)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_visa_openai` with `{'nationality': 'Indian', 'destination_country': 'Australia'}`
#
#
# - Visa Requirement: Yes, Indian citizens require a visa to travel to Australia.
# - Type of Visa: The type of visa required depends on the purpose of the visit. For tourism, a Visitor visa (subclass 600) is typically needed. For work, a Work visa (subclass 400) may be required. For studying, a Student visa (subclass 500) is usually necessary.
# - Duration of Stay: The duration of stay allowed depends on the type of visa granted. For a Visitor visa, the stay can be up to 3, 6 or 12 months. Work and Student visas may allow longer stays, depending on the nature of the work or study.
# - Key Documents Typically Required:
#   - A valid Indian passport
#   - Completed Australian visa application form
#   - Passport-sized photographs
#   - Proof of sufficient funds to cover your stay (bank statements, pay slips, etc.)
#   - For a Visitor visa, a detailed itinerary of your stay
#   - For a Work visa, a letter from your employer detailing your role, duration of employment, etc.
#   - For a Student visa, a Confirmation of Enrolment (CoE) from your Australian educational institution
# - Disclaimer: This is a general guidance and the requirements may vary. Please consult the official website of the Australian Department of Home Affairs or contact the Australian embassy or consulate in India for the most accurate and up-to-date information.
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 400) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed depends on the type of visa granted. For a Visitor visa, the stay can be up to 3, 6 or 12 months. Work and Student visas may allow longer stays, depending on the nature of the work or study.
#
# Key documents typically required include:
#
# - A valid Indian passport
# - Completed Australian visa application form
# - Passport-sized photographs
# - Proof of sufficient funds to cover your stay (bank statements, pay slips, etc.)
# - For a Visitor visa, a detailed itinerary of your stay
# - For a Work visa, a letter from your employer detailing your role, duration of employment, etc.
# - For a Student visa, a Confirmation of Enrolment (CoE) from your Australian educational institution
#
# Please note that this is a general guidance and the requirements may vary. I recommend consulting the official website of the Australian Department of Home Affairs or contacting the Australian embassy or consulate in India for the most accurate and up-to-date information.
#
# > Finished chain.
#
# Invoking: `calculate_budget_plan` with `{'budget': 2000, 'currency': 'USD'}`
#
#
# Trip Budget Planner:
# -----------------------
# Flights     : 800.0 USD
# Hotels      : 600.0 USD
# Activities  : 400.0 USD
# Other Costs : 200.0 USD
# -----------------------
# Total Budget: 2000.0 USD
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# The total budget for your trip is $2000.00.
#
# > Finished chain.
#
# Invoking: `search_flights_openai` with `{'origin': 'Mumbai', 'destination': 'Melbourne', 'date': '2025-05-24'}`
#
#
# Option 1:
# - Airline: Air India
# - Departure: 00:30, Arrival: 15:30
# - Duration: 15 hours
# - Estimated Price: INR 55,000
# - Booking: [www.airindia.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 2:
# - Airline: Qantas Airways
# - Departure: 02:45, Arrival: 18:15
# - Duration: 15 hours 30 minutes
# - Estimated Price: INR 60,000
# - Booking: [www.qantas.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 3:
# - Airline: Emirates
# - Departure: 04:15, Arrival: 20:00
# - Duration: 15 hours 45 minutes
# - Estimated Price: INR 65,000
# - Booking: [www.emirates.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 4:
# - Airline: Singapore Airlines
# - Departure: 23:45, Arrival: 14:30
# - Duration: 14 hours 45 minutes
# - Estimated Price: INR 58,000
# - Booking: [www.singaporeair.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 5:
# - Airline: Cathay Pacific
# - Departure: 01:15, Arrival: 16:00
# - Duration: 14 hours 45 minutes
# - Estimated Price: INR 57,000
# - Booking: [www.cathaypacific.com/booking/MUM-MEL/2025-05-24](#)
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here are some flight options from Mumbai to Melbourne on May 24, 2025:
#
# 1. [Air India](#): Departure at 00:30, Arrival at 15:30. The duration is 15 hours. The estimated price is INR 55,000.
#
# 2. [Qantas Airways](#): Departure at 02:45, Arrival at 18:15. The duration is 15 hours 30 minutes. The estimated price is INR 60,000.
#
# 3. [Emirates](#): Departure at 04:15, Arrival at 20:00. The duration is 15 hours 45 minutes. The estimated price is INR 65,000.
#
# 4. [Singapore Airlines](#): Departure at 23:45, Arrival at 14:30. The duration is 14 hours 45 minutes. The estimated price is INR 58,000.
#
# 5. [Cathay Pacific](#): Departure at 01:15, Arrival at 16:00. The duration is 14 hours 45 minutes. The estimated price is INR 57,000.
#
# Please note that these are estimated prices and the actual prices may vary. You can click on the airline name to go to the booking page.
#
# > Finished chain.
#
# Invoking: `search_hotels_openai` with `{'to_city': 'Melbourne', 'check_in': '2025-05-24', 'check_out': '2025-05-30', 'hotel_budget': 200}`
#
#
# I'm sorry, but it's highly unlikely to find hotels in Melbourne that would fit within a total budget of $200 for a 6-night stay. The average price per night for a hotel in Melbourne is typically over $100. However, I can suggest some budget-friendly options that might stretch your budget a little further:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget hotel offers basic amenities and is close to public transportation, making it easy to explore the city. It's a good fit for budget travelers.
#    - Estimated price/night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This budget-friendly hotel is located in Melbourne CBD and offers dormitory-style rooms. It's suitable for backpackers or solo travelers.
#    - Estimated price/night: $50
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located close to Queen Victoria Market. It offers both private rooms and dormitory-style rooms. It's suitable for backpackers or solo travelers.
#    - Estimated price/night: $40
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices can fluctuate and may be higher during peak travel times. It's always best to book in advance to secure the best rates.
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here are some budget-friendly options in Melbourne for your stay from May 24 to May 30, 2025:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget hotel offers basic amenities and is close to public transportation, making it easy to explore the city. It's a good fit for budget travelers.
#    - Estimated price per night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This budget-friendly hotel is located in Melbourne CBD and offers dormitory-style rooms. It's suitable for backpackers or solo travelers.
#    - Estimated price per night: $50
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located close to Queen Victoria Market. It offers both private rooms and dormitory-style rooms. It's suitable for backpackers or solo travelers.
#    - Estimated price per night: $40
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices can fluctuate and may be higher during peak travel times. It's always best to book in advance to secure the best rates.
#
# > Finished chain.
#
# Invoking: `search_activities_openai` with `{'to_city': 'Melbourne', 'travel_days': 7, 'interests': ['budget-friendly']}`
#
#
# Day 1:
# - Activity: Melbourne City Tour
#   Description: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a city tour.
#   Type: Cultural
#   Booking: www.melbournecitytours.com
#
# Day 2:
# - Activity: Queen Victoria Market
#   Description: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs.
#   Type: Food & Shopping
#   Reference: www.queenvictoriamarket.com.au
#
# Day 3:
# - Activity: Melbourne Street Art Tour
#   Description: Discover Melbourne's vibrant street art scene in the famous laneways of the city.
#   Type: Cultural
#   Booking: www.melbournestreetarttour.com
#
# Day 4:
# - Activity: St Kilda Beach
#   Description: Enjoy a day at St Kilda Beach, perfect for swimming, sunbathing, and people-watching.
#   Type: Adventure
#   Reference: www.visitstkilda.com.au
#
# Day 5:
# - Activity: Royal Botanic Gardens
#   Description: Explore the lush landscapes and diverse plant life at the Royal Botanic Gardens.
#   Type: Nature
#   Reference: www.rbg.vic.gov.au
#
# Day 6:
# - Activity: Melbourne Museum
#   Description: Visit the Melbourne Museum to learn about the city's history, culture, and natural environment.
#   Type: Cultural
#   Booking: www.melbournemuseum.com.au
#
# Day 7:
# - Activity: Free Walking Tour
#   Description: Join a free walking tour to explore Melbourne's hidden gems and local favorites.
#   Type: Cultural
#   Booking: www.freewalkingtourmelbourne.com.au
# Here are some budget-friendly activities you can do in Melbourne from May 24 to May 30, 2025:
#
# Day 1:
# - **Melbourne City Tour**: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a city tour. [Book here](www.melbournecitytours.com)
#
# Day 2:
# - **Queen Victoria Market**: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs. [More info](www.queenvictoriamarket.com.au)
#
# Day 3:
# - **Melbourne Street Art Tour**: Discover Melbourne's vibrant street art scene in the famous laneways of the city. [Book here](www.melbournestreetarttour.com)
#
# Day 4:
# - **St Kilda Beach**: Enjoy a day at St Kilda Beach, perfect for swimming, sunbathing, and people-watching. [More info](www.visitstkilda.com.au)
#
# Day 5:
# - **Royal Botanic Gardens**: Explore the lush landscapes and diverse plant life at the Royal Botanic Gardens. [More info](www.rbg.vic.gov.au)
#
# Day 6:
# - **Melbourne Museum**: Visit the Melbourne Museum to learn about the city's history, culture, and natural environment. [Book here](www.melbournemuseum.com.au)
#
# Day 7:
# - **Free Walking Tour**: Join a free walking tour to explore Melbourne's hidden gems and local favorites. [Book here](www.freewalkingtourmelbourne.com.au)
#
# Please note that while the activities themselves are budget-friendly, there may be additional costs for food, souvenirs, and transportation.
#
# > Finished chain.
# Visa Response: Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 400) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed depends on the type of visa granted. For a Visitor visa, the stay can be up to 3, 6 or 12 months. Work and Student visas may allow longer stays, depending on the nature of the work or study.
#
# Key documents typically required include:
#
# - A valid Indian passport
# - Completed Australian visa application form
# - Passport-sized photographs
# - Proof of sufficient funds to cover your stay (bank statements, pay slips, etc.)
# - For a Visitor visa, a detailed itinerary of your stay
# - For a Work visa, a letter from your employer detailing your role, duration of employment, etc.
# - For a Student visa, a Confirmation of Enrolment (CoE) from your Australian educational institution
#
# Please note that this is a general guidance and the requirements may vary. I recommend consulting the official website of the Australian Department of Home Affairs or contacting the Australian embassy or consulate in India for the most accurate and up-to-date information.
# Budget Response: Here is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# The total budget for your trip is $2000.00.
# Flight Response: Here are some flight options from Mumbai to Melbourne on May 24, 2025:
#
# 1. [Air India](#): Departure at 00:30, Arrival at 15:30. The duration is 15 hours. The estimated price is INR 55,000.
#
# 2. [Qantas Airways](#): Departure at 02:45, Arrival at 18:15. The duration is 15 hours 30 minutes. The estimated price is INR 60,000.
#
# 3. [Emirates](#): Departure at 04:15, Arrival at 20:00. The duration is 15 hours 45 minutes. The estimated price is INR 65,000.
#
# 4. [Singapore Airlines](#): Departure at 23:45, Arrival at 14:30. The duration is 14 hours 45 minutes. The estimated price is INR 58,000.
#
# 5. [Cathay Pacific](#): Departure at 01:15, Arrival at 16:00. The duration is 14 hours 45 minutes. The estimated price is INR 57,000.
#
# Please note that these are estimated prices and the actual prices may vary. You can click on the airline name to go to the booking page.
# Hotel Response: Here are some budget-friendly options in Melbourne for your stay from May 24 to May 30, 2025:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget hotel offers basic amenities and is close to public transportation, making it easy to explore the city. It's a good fit for budget travelers.
#    - Estimated price per night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This budget-friendly hotel is located in Melbourne CBD and offers dormitory-style rooms. It's suitable for backpackers or solo travelers.
#    - Estimated price per night: $50
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located close to Queen Victoria Market. It offers both private rooms and dormitory-style rooms. It's suitable for backpackers or solo travelers.
#    - Estimated price per night: $40
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices can fluctuate and may be higher during peak travel times. It's always best to book in advance to secure the best rates.
# Activity Response: Here are some budget-friendly activities you can do in Melbourne from May 24 to May 30, 2025:
#
# Day 1:
# - **Melbourne City Tour**: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a city tour. [Book here](www.melbournecitytours.com)
#
# Day 2:
# - **Queen Victoria Market**: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs. [More info](www.queenvictoriamarket.com.au)
#
# Day 3:
# - **Melbourne Street Art Tour**: Discover Melbourne's vibrant street art scene in the famous laneways of the city. [Book here](www.melbournestreetarttour.com)
#
# Day 4:
# - **St Kilda Beach**: Enjoy a day at St Kilda Beach, perfect for swimming, sunbathing, and people-watching. [More info](www.visitstkilda.com.au)
#
# Day 5:
# - **Royal Botanic Gardens**: Explore the lush landscapes and diverse plant life at the Royal Botanic Gardens. [More info](www.rbg.vic.gov.au)
#
# Day 6:
# - **Melbourne Museum**: Visit the Melbourne Museum to learn about the city's history, culture, and natural environment. [Book here](www.melbournemuseum.com.au)
#
# Day 7:
# - **Free Walking Tour**: Join a free walking tour to explore Melbourne's hidden gems and local favorites. [Book here](www.freewalkingtourmelbourne.com.au)
#
# Please note that while the activities themselves are budget-friendly, there may be additional costs for food, souvenirs, and transportation.

# %%
from agents.visa_agent import get_visa_agent
from agents.budget_agent import get_budget_agent
from agents.flight_agent import get_flight_agent
from agents.hotel_agent import get_hotel_agent
from agents.activity_agent import get_activity_agent

visa_agent = get_visa_agent()
budget_agent = get_budget_agent()
flight_agent = get_flight_agent()
hotel_agent = get_hotel_agent()
activity_agent = get_activity_agent()

visa_response = visa_agent.run("visa requirements for Indian citizens traveling to Australia")
budget_response = budget_agent.run("budget plan for a trip to Melbourne from May 24 to May 30, 2025 with a budget of $2000")
flight_response = flight_agent.run("flight options from Mumbai to Melbourne on May 24, 2025")
hotel_response = hotel_agent.run("hotel options in Melbourne from May 24 to May 30, 2025 under $200")
activity_response = activity_agent.run("activities in Melbourne from May 24 to May 30, 2025 under $100")

print("Visa Response:", visa_response)
print("\n"+"-"*80+"\n")
print("Budget Response:", budget_response)
print("\n"+"-"*80+"\n")
print("Flight Response:", flight_response)
print("\n"+"-"*80+"\n")
print("Hotel Response:", hotel_response)
print("\n"+"-"*80+"\n")
print("Activity Response:", activity_response)
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Invoking: `search_visa_openai` with `{'nationality': 'Indian', 'destination_country': 'Australia'}`
#
#
# - Visa Requirement: Yes, Indian citizens require a visa to travel to Australia.
# - Type of Visa: The type of visa required depends on the purpose of the visit. For tourism, a Visitor visa (subclass 600) is typically needed. For work, a Work visa (subclass 457) may be required. For studying, a Student visa (subclass 500) is usually necessary.
# - Duration of Stay: The duration of stay allowed varies depending on the visa type. For a Visitor visa, the stay can be up to 3, 6 or 12 months. For a Work visa, the stay can be up to 4 years. For a Student visa, the stay duration is usually the same as the duration of the course.
# - Key Documents Required: The documents required also depend on the visa type. However, generally, you will need a valid passport, proof of sufficient funds, health and character certificates, proof of return or onward travel, and any additional documents that support your visa application (like employment or study documents).
# - Disclaimer: This is a general guidance and the requirements may vary. Please consult the official Australian Government Department of Home Affairs website or contact the Australian embassy or consulate in India for the most accurate and up-to-date information.
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 457) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed varies depending on the visa type.
#
# - For a Visitor visa, the stay can be up to 3, 6 or 12 months.
# - For a Work visa, the stay can be up to 4 years.
# - For a Student visa, the stay duration is usually the same as the duration of the course.
#
# Key documents required generally include a valid passport, proof of sufficient funds, health and character certificates, proof of return or onward travel, and any additional documents that support your visa application (like employment or study documents).
#
# Please note that this is a general guidance and the requirements may vary. It's recommended to consult the official Australian Government Department of Home Affairs website or contact the Australian embassy or consulate in India for the most accurate and up-to-date information.
#
# > Finished chain.
#
# Invoking: `calculate_budget_plan` with `{'budget': 2000, 'currency': 'USD'}`
#
#
# Trip Budget Planner:
# -----------------------
# Flights     : 800.0 USD
# Hotels      : 600.0 USD
# Activities  : 400.0 USD
# Other Costs : 200.0 USD
# -----------------------
# Total Budget: 2000.0 USD
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# Total Budget: $2000.00
#
# Please note that these are estimated costs and actual costs may vary.
#
# > Finished chain.
#
# Invoking: `search_flights_openai` with `{'origin': 'Mumbai', 'destination': 'Melbourne', 'date': '2025-05-24'}`
#
#
# Option 1:
# - Airline: Air India
# - Departure: 20:00, Arrival: 15:30 (+1 day)
# - Duration: 13h 30m
# - Price: INR 55,000
# - Booking: [www.airindia.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 2:
# - Airline: Qantas Airways
# - Departure: 22:30, Arrival: 18:00 (+1 day)
# - Duration: 14h 30m
# - Price: INR 60,000
# - Booking: [www.qantas.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 3:
# - Airline: Emirates
# - Departure: 04:15, Arrival: 20:45
# - Duration: 20h 30m (1 stop)
# - Price: INR 65,000
# - Booking: [www.emirates.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 4:
# - Airline: Singapore Airlines
# - Departure: 23:45, Arrival: 19:15 (+1 day)
# - Duration: 15h 30m
# - Price: INR 58,000
# - Booking: [www.singaporeair.com/booking/MUM-MEL/2025-05-24](#)
#
# Option 5:
# - Airline: Cathay Pacific
# - Departure: 01:10, Arrival: 13:40
# - Duration: 16h 30m (1 stop)
# - Price: INR 62,000
# - Booking: [www.cathaypacific.com/booking/MUM-MEL/2025-05-24](#)
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here are some flight options from Mumbai to Melbourne on May 24, 2025:
#
# **Option 1:**
# - Airline: Air India
# - Departure: 20:00, Arrival: 15:30 (+1 day)
# - Duration: 13h 30m
# - Price: INR 55,000
# - [Book here](#)
#
# **Option 2:**
# - Airline: Qantas Airways
# - Departure: 22:30, Arrival: 18:00 (+1 day)
# - Duration: 14h 30m
# - Price: INR 60,000
# - [Book here](#)
#
# **Option 3:**
# - Airline: Emirates
# - Departure: 04:15, Arrival: 20:45
# - Duration: 20h 30m (1 stop)
# - Price: INR 65,000
# - [Book here](#)
#
# **Option 4:**
# - Airline: Singapore Airlines
# - Departure: 23:45, Arrival: 19:15 (+1 day)
# - Duration: 15h 30m
# - Price: INR 58,000
# - [Book here](#)
#
# **Option 5:**
# - Airline: Cathay Pacific
# - Departure: 01:10, Arrival: 13:40
# - Duration: 16h 30m (1 stop)
# - Price: INR 62,000
# - [Book here](#)
#
# Please note that prices and availability are subject to change. It's always a good idea to check the airline's official website for the most accurate and up-to-date information.
#
# > Finished chain.
#
# Invoking: `search_hotels_openai` with `{'to_city': 'Melbourne', 'check_in': '2025-05-24', 'check_out': '2025-05-30', 'hotel_budget': 200}`
#
#
# I'm sorry, but it's highly unlikely to find a hotel in Melbourne for a week-long stay under a total budget of $200. The cost of living in Melbourne is quite high, and even budget hotels typically charge around $50-$100 per night. However, I can suggest some budget-friendly options that you might want to consider:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget hotel offers basic amenities and is close to public transportation, making it suitable for budget travelers.
#    - Estimated price/night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This is a budget-friendly hostel located in Melbourne CBD. It offers shared and private rooms, making it suitable for solo travelers or groups.
#    - Estimated price/night: $50 for a shared room
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located near the Queen Victoria Market. It offers shared rooms and is suitable for backpackers and solo travelers.
#    - Estimated price/night: $40 for a shared room
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices can fluctuate depending on the season and availability. I would recommend increasing your budget if possible to ensure a comfortable stay.
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Here are some budget-friendly hotel options in Melbourne for your stay from May 24 to May 30, 2025:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget hotel offers basic amenities and is close to public transportation, making it suitable for budget travelers.
#    - Estimated price/night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This is a budget-friendly hostel located in Melbourne CBD. It offers shared and private rooms, making it suitable for solo travelers or groups.
#    - Estimated price/night: $50 for a shared room
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located near the Queen Victoria Market. It offers shared rooms and is suitable for backpackers and solo travelers.
#    - Estimated price/night: $40 for a shared room
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices can fluctuate depending on the season and availability. I would recommend increasing your budget if possible to ensure a comfortable stay.
#
# > Finished chain.
#
# Invoking: `search_activities_openai` with `{'to_city': 'Melbourne', 'travel_days': 7, 'interests': ['budget-friendly']}`
#
#
# Day 1:
# - Activity: Melbourne City Tour
#   Description: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a city tour.
#   Type: Cultural
#   Booking: www.melbournecitytours.com
#
# Day 2:
# - Activity: Queen Victoria Market
#   Description: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs.
#   Type: Food & Shopping
#   Reference: www.queenvictoriamarket.com.au
#
# Day 3:
# - Activity: Melbourne Zoo
#   Description: Discover over 320 species from around the world in a beautifully landscaped setting.
#   Type: Adventure
#   Booking: www.zoo.org.au/melbourne
#
# Day 4:
# - Activity: Melbourne Museum
#   Description: Explore Australia's cultural history with exhibits on Aboriginal culture, the country's flora and fauna, and more.
#   Type: Cultural
#   Booking: www.museumsvictoria.com.au/melbournemuseum
#
# Day 5:
# - Activity: St Kilda Beach
#   Description: Enjoy a day at the beach, with opportunities for swimming, sunbathing, and beach volleyball.
#   Type: Leisure
#   Reference: www.visitstkilda.com.au
#
# Day 6:
# - Activity: Royal Botanic Gardens
#   Description: Wander through a collection of more than 8,500 plant species, lush lawns, and tranquil lakes.
#   Type: Leisure
#   Reference: www.rbg.vic.gov.au
#
# Day 7:
# - Activity: Yarra River Cruise
#   Description: Enjoy a scenic cruise along the Yarra River, offering stunning views of Melbourne's skyline and parks.
#   Type: Adventure
#   Booking: www.yarrarivercruises.com.au
# Here are some budget-friendly activities in Melbourne from May 24 to May 30, 2025:
#
# Day 1:
# - **Melbourne City Tour**: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a city tour. [Book here](www.melbournecitytours.com)
#
# Day 2:
# - **Queen Victoria Market**: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs. [More info](www.queenvictoriamarket.com.au)
#
# Day 3:
# - **Melbourne Zoo**: Discover over 320 species from around the world in a beautifully landscaped setting. [Book here](www.zoo.org.au/melbourne)
#
# Day 4:
# - **Melbourne Museum**: Explore Australia's cultural history with exhibits on Aboriginal culture, the country's flora and fauna, and more. [Book here](www.museumsvictoria.com.au/melbournemuseum)
#
# Day 5:
# - **St Kilda Beach**: Enjoy a day at the beach, with opportunities for swimming, sunbathing, and beach volleyball. [More info](www.visitstkilda.com.au)
#
# Day 6:
# - **Royal Botanic Gardens**: Wander through a collection of more than 8,500 plant species, lush lawns, and tranquil lakes. [More info](www.rbg.vic.gov.au)
#
# Day 7:
# - **Yarra River Cruise**: Enjoy a scenic cruise along the Yarra River, offering stunning views of Melbourne's skyline and parks. [Book here](www.yarrarivercruises.com.au)
#
# Please note that prices can vary, so it's a good idea to check the websites for the most current information. Enjoy your trip!
#
# > Finished chain.
# Visa Response: Indian citizens require a visa to travel to Australia. The type of visa you need depends on the purpose of your visit.
#
# - For tourism, a Visitor visa (subclass 600) is typically needed.
# - For work, a Work visa (subclass 457) may be required.
# - For studying, a Student visa (subclass 500) is usually necessary.
#
# The duration of stay allowed varies depending on the visa type.
#
# - For a Visitor visa, the stay can be up to 3, 6 or 12 months.
# - For a Work visa, the stay can be up to 4 years.
# - For a Student visa, the stay duration is usually the same as the duration of the course.
#
# Key documents required generally include a valid passport, proof of sufficient funds, health and character certificates, proof of return or onward travel, and any additional documents that support your visa application (like employment or study documents).
#
# Please note that this is a general guidance and the requirements may vary. It's recommended to consult the official Australian Government Department of Home Affairs website or contact the Australian embassy or consulate in India for the most accurate and up-to-date information.
#
# --------------------------------------------------------------------------------
#
# Budget Response: Here is your budget plan for your trip to Melbourne from May 24 to May 30, 2025:
#
# - Flights: $800.00
# - Hotels: $600.00
# - Activities: $400.00
# - Other Costs: $200.00
#
# Total Budget: $2000.00
#
# Please note that these are estimated costs and actual costs may vary.
#
# --------------------------------------------------------------------------------
#
# Flight Response: Here are some flight options from Mumbai to Melbourne on May 24, 2025:
#
# **Option 1:**
# - Airline: Air India
# - Departure: 20:00, Arrival: 15:30 (+1 day)
# - Duration: 13h 30m
# - Price: INR 55,000
# - [Book here](#)
#
# **Option 2:**
# - Airline: Qantas Airways
# - Departure: 22:30, Arrival: 18:00 (+1 day)
# - Duration: 14h 30m
# - Price: INR 60,000
# - [Book here](#)
#
# **Option 3:**
# - Airline: Emirates
# - Departure: 04:15, Arrival: 20:45
# - Duration: 20h 30m (1 stop)
# - Price: INR 65,000
# - [Book here](#)
#
# **Option 4:**
# - Airline: Singapore Airlines
# - Departure: 23:45, Arrival: 19:15 (+1 day)
# - Duration: 15h 30m
# - Price: INR 58,000
# - [Book here](#)
#
# **Option 5:**
# - Airline: Cathay Pacific
# - Departure: 01:10, Arrival: 13:40
# - Duration: 16h 30m (1 stop)
# - Price: INR 62,000
# - [Book here](#)
#
# Please note that prices and availability are subject to change. It's always a good idea to check the airline's official website for the most accurate and up-to-date information.
#
# --------------------------------------------------------------------------------
#
# Hotel Response: Here are some budget-friendly hotel options in Melbourne for your stay from May 24 to May 30, 2025:
#
# 1. **Ibis Budget Melbourne CBD**
#    - Located in the heart of Melbourne, this budget hotel offers basic amenities and is close to public transportation, making it suitable for budget travelers.
#    - Estimated price/night: $70
#    - [Book here](www.ibisbudgetmelbourne.com)
#
# 2. **Space Hotel**
#    - This is a budget-friendly hostel located in Melbourne CBD. It offers shared and private rooms, making it suitable for solo travelers or groups.
#    - Estimated price/night: $50 for a shared room
#    - [Book here](www.spacehotel.com.au)
#
# 3. **Melbourne Metro YHA**
#    - A budget-friendly hostel located near the Queen Victoria Market. It offers shared rooms and is suitable for backpackers and solo travelers.
#    - Estimated price/night: $40 for a shared room
#    - [Book here](www.yha.com.au/hostels/vic/melbourne-hostels/melbourne-metro-yha)
#
# Please note that prices can fluctuate depending on the season and availability. I would recommend increasing your budget if possible to ensure a comfortable stay.
#
# --------------------------------------------------------------------------------
#
# Activity Response: Here are some budget-friendly activities in Melbourne from May 24 to May 30, 2025:
#
# Day 1:
# - **Melbourne City Tour**: Explore Melbourne's iconic landmarks, beautiful parks, and historic sites on a city tour. [Book here](www.melbournecitytours.com)
#
# Day 2:
# - **Queen Victoria Market**: Visit the largest open-air market in the Southern Hemisphere, offering a variety of food, clothing, and souvenirs. [More info](www.queenvictoriamarket.com.au)
#
# Day 3:
# - **Melbourne Zoo**: Discover over 320 species from around the world in a beautifully landscaped setting. [Book here](www.zoo.org.au/melbourne)
#
# Day 4:
# - **Melbourne Museum**: Explore Australia's cultural history with exhibits on Aboriginal culture, the country's flora and fauna, and more. [Book here](www.museumsvictoria.com.au/melbournemuseum)
#
# Day 5:
# - **St Kilda Beach**: Enjoy a day at the beach, with opportunities for swimming, sunbathing, and beach volleyball. [More info](www.visitstkilda.com.au)
#
# Day 6:
# - **Royal Botanic Gardens**: Wander through a collection of more than 8,500 plant species, lush lawns, and tranquil lakes. [More info](www.rbg.vic.gov.au)
#
# Day 7:
# - **Yarra River Cruise**: Enjoy a scenic cruise along the Yarra River, offering stunning views of Melbourne's skyline and parks. [Book here](www.yarrarivercruises.com.au)
#
# Please note that prices can vary, so it's a good idea to check the websites for the most current information. Enjoy your trip!
